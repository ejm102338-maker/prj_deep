# %%
import requests

url = "http://localhost:6003/infer"

with open('./img/image_4.jpg','rb') as f:
    response = requests.post(url,files={'file':f})
    
response

# %%
response.json()
# Out:
# {'result': '장원영',
#  'index': 2,
#  'filename': 'b8f457c9-c6fe-4615-826f-7c8f14375e8d.jpg'}
