# %%
import torch
import torch.nn as nn 
import torch.optim as optim
import torchvision.models as models
import torchvision.transforms as transforms
import pandas as pd
import os
import optuna
import numpy as np
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from PIL import Image
from torch.utils.data import random_split
from tqdm.auto import tqdm
from PIL import Image, ImageFile
from sqlalchemy import create_engine
from torch.utils.tensorboard import SummaryWriter
import datetime
# Out:
# notebook controller is DISPOSED.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %%
# 1. 하이퍼파라미터 및 경로 설정
CSV_PATH = "data/datasets_local/DATA_LABELS_TOTAL.csv"
IMG_DIR = "data/datasets_local/images"
EPOCHS = 1 # 테스트위해 한번만 돌림 (10)
n_trials = 1 # 50 테스트를 위해 5번만 돌림

# %%
img_extensions = ('.jpg', '.jpeg', '.png', '.bmp','.gif')

# %%
df = pd.read_csv(CSV_PATH)
print(df.columns)
# Out:
# Index(['folder_name', 'file_name', '문화재', '문화', '자연', '테마공원', '시장', '거리', '공원',
#        '데이트/로맨틱', '힐링/여유', '액티브/아웃도어', '가족/키즈', '야경/밤감성', '장소명', 'Place Name',
#        '장소 설명', 'Place Description'],
#       dtype='object')

# %% [markdown]
# # 컬럼정보

# %%
LABELS_P1 = df.columns[2:9]
LABELS_P2 = df.columns[9:14]
print(LABELS_P1)
print(LABELS_P2)
# Out:
# Index(['문화재', '문화', '자연', '테마공원', '시장', '거리', '공원'], dtype='object')
# Index(['데이트/로맨틱', '힐링/여유', '액티브/아웃도어', '가족/키즈', '야경/밤감성'], dtype='object')

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# c:\potenup3\prj_deep\.venv\Lib\site-packages\torch\cuda\__init__.py:184: UserWarning: cudaGetDeviceCount() returned cudaErrorNotSupported, likely using older driver or on CPU machine (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\c10\cuda\CUDAFunctions.cpp:88.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# # 멀티레이블 정의

# %%
class MultiLabelDataset(Dataset):
 
    def __init__(self, csv_file, img_dir, transform=None):
        self.df = pd.read_csv(csv_file)
        #print(self.data.head(1))
        self.img_dir = img_dir
        self.transform = transform
        #self.label_range = label_range

        # CSV 컬럼명에 맞춰 조정 필요 (예: ['label1', ..., 'label6'])
        self.labels_p1 = LABELS_P1
        self.labels_p2 = LABELS_P2

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_name = self.df.iloc[idx]['file_name']
        img_path = f"{self.img_dir}/{img_name}"
        image = Image.open(img_path).convert('RGB')
        
        labels1 = torch.tensor(self.df.iloc[idx][self.labels_p1].values.astype(float), dtype=torch.float32)
        labels2 = torch.tensor(self.df.iloc[idx][self.labels_p2].values.astype(float), dtype=torch.float32)
        
        if self.transform:
            image = self.transform(image)
            
        return image, labels1, labels2

# %% [markdown]
# # 전처리 및 데이터셋 설정

# %%
# 데이터 증강 (Best 모델을 위한 필수 단계)
# 학습 데이터에는 변형을 주어 일반화 성능을 높이고, 검증 데이터는 원본 유지
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(), # 좌우 반전
    transforms.RandomRotation(10),     # 살짝 회전
    transforms.ColorJitter(brightness=0.2, contrast=0.2), # 밝기/대비 조절
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# 데이터셋 분할
dataset = MultiLabelDataset(csv_file=CSV_PATH, img_dir=IMG_DIR, transform=train_transform)

train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_data, val_data = random_split(dataset, [train_size, val_size])

# 검증 셋에는 변형이 없는 val_transform 적용 
val_data.dataset.transform = val_transform

# 모델 생성 함수 (EfficientNet-B0)
def create_model(num_classes):
    # ImageNet으로 사전 학습된 가중치를 베이스로 사용하여 성능을 극대화합니다.
    model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.DEFAULT)
    # 출력 레이어를 사용자의 레이블 개수에 맞게 변경
    model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
    return model.to(DEVICE)

# %% [markdown]
# # OPTUNA 정의 및 EfficientNet 모델 학습

# %%
# Optuna용 목적 함수(Objective Function) 정의
# 베스트 손실값을 추적하기 위한 전역 변수 설정
best_val_loss = 0

# 베스트 손실값을 추적하기 위한 전역 변수 초기화 (매우 큰 값으로)
best_loss_part1 = 100
best_loss_part2 = 100

def objective(trial, target_part):
    global best_loss_part1, best_loss_part2 # 전역 변수 사용 선언

    # TensorBoard SummaryWriter 설정
    log_dir = os.path.join("runs", f"part_{target_part}", f"trial_{trial.number}")
    writer = SummaryWriter(log_dir)


    # 하이퍼파라미터 탐색 범위 설정
    lr = trial.suggest_float("lr", 1e-5, 1e-3, log=True)
    batch_size = trial.suggest_categorical("batch_size", [16, 32, 64, 128])
    optimizer_name = "AdamW" #trial.suggest_categorical("optimizer", ["AdamW", "RMSprop"])
    
    # 데이터 로더 재설정 (배치 사이즈 변경 대응)
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)

    # 모델 생성
    num_class = len(LABELS_P1) if target_part == 1 else len(LABELS_P2)
    model = create_model(num_classes=num_class).to(DEVICE)
    #criterion = nn.BCEWithLogitsLoss()
    criterion = nn.CrossEntropyLoss()
    
    optimizer = optim.AdamW(model.parameters(), lr=lr)

    # 학습
    for epoch in range(EPOCHS): 
        model.train()
        train_loss = 0.0
        train_correct = 0
        train_total = 0

        for imgs, labels1, labels2 in tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS}"):
            imgs = imgs.to(DEVICE)
            # target_part 값에 따라 레이블 선택
            raw_targets = labels1.to(DEVICE) if target_part == 1 else labels2.to(DEVICE)

            # [핵심 수정] raw_targets를 1차원으로 만듭니다.
            # 만약 [128, 7] 형태라면 argmax를, [128, 1] 형태라면 squeeze를 사용합니다.
            if raw_targets.dim() > 1:
                if raw_targets.size(-1) > 1: # 원-핫 인코딩 형태일 때
                    raw_targets = raw_targets.argmax(dim=1)
                else: # [128, 1] 처럼 차원만 하나 더 있을 때
                    raw_targets = raw_targets.squeeze()

            # 이제 raw_targets는 [128] 크기의 1차원 텐서입니다.
            # 따라서 생성되는 mask도 [128] 크기의 1차원이 됩니다.
            if target_part == 1:
                mask = (raw_targets >= 0) & (raw_targets <= 6)
            else:
                mask = (raw_targets >= 7) & (raw_targets <= 12)

            if not mask.any(): 
                continue

            # 3. 필터링 적용
            imgs = imgs[mask]
            targets = raw_targets[mask]

            # 4. Part 2 레이블 조정 (7~12 -> 0~5)
            if target_part == 2:
                targets = targets - 7





            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            # 통계 계산
            train_loss += loss.item()
            _, predicted = outputs.max(1)
            train_total += targets.size(0)
            train_correct += predicted.eq(targets).sum().item()

        avg_train_loss = train_loss / len(train_loader)
        train_acc = 100. * train_correct / train_total

        # 검증
        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for imgs, labels1, labels2 in val_loader:
                
                imgs = imgs.to(DEVICE)
                # target_part 값에 따라 레이블 선택
                targets = labels1.to(DEVICE) if target_part == 1 else labels2.to(DEVICE)

                imgs, targets = imgs.to(DEVICE), targets
                outputs = model(imgs)
                val_loss += criterion(outputs, targets).item()
        
        avg_val_loss = val_loss / len(val_loader)
        val_acc = 100. * val_correct / val_total

        # TensorBoard 기록 (Scalars)
        writer.add_scalar('Loss/Train', avg_train_loss, epoch)
        writer.add_scalar('Loss/Validation', avg_val_loss, epoch)
        writer.add_scalar('Accuracy/Train', train_acc, epoch)
        writer.add_scalar('Accuracy/Validation', val_acc, epoch)
        writer.flush()



        # 전역 변수와 비교하여 모델 저장 여부 결정
        current_best = best_loss_part1 if target_part == 1 else best_loss_part2

        if avg_val_loss < current_best:
            if target_part == 1:
                best_loss_part1 = avg_val_loss
            else:
                best_loss_part2 = avg_val_loss

            best_val_loss =  avg_val_loss
            
            # 파일명에 trial 번호를 붙이거나 고정된 이름을 사용
            torch.save(model.state_dict(), f"optuna_best_model_efficientnet_part{target_part}_test.pth")
            print(f"New Best Model Saved at Trial {trial.number} (Loss: {best_val_loss:.4f})")

        # 중간 결과 보고 및 가지치기(Pruning): 가능성 없는 실험 조기 중단
        trial.report(avg_val_loss, epoch)
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()
        
        # 하이퍼파라미터 요약 기록 (Hparams 탭)
        writer.add_hparams(
            {"lr": lr, "batch_size": batch_size},
            {"hparam/val_loss": avg_val_loss, "hparam/val_acc": val_acc}
        )

        
    writer.close()
    return avg_val_loss

# %% [markdown]
# ## 학습 시작 (결과연동)

# %%
print("Part 1 최적화 시작...")
place_study = optuna.create_study(
    study_name="place_study_efficientnet",
    storage="postgresql+psycopg2://duruser:durpass@172.16.100.21:5432/place",
    load_if_exists=True,
    direction="minimize",
)
place_study.optimize(lambda t: objective(t, target_part=1), n_trials=n_trials)


# print("\nPart 2 최적화 시작...")
# theme_studyd = optuna.create_study(
#     study_name="theme_study_efficientnet",
#     storage="postgresql+psycopg2://duruser:durpass@172.16.100.21:5432/theme",
#     load_if_exists=True,
#     direction="minimize",
# )
# theme_studyd.optimize(lambda t: objective(t, target_part=2), n_trials=n_trials)
# Out:
# Part 1 최적화 시작...
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3317, in Engine.raw_connection(self)
#    3296 """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298 The returned object is a proxied version of the DBAPI
#    (...)   3315
#    3316 """
# -> 3317 return self.pool.connect()
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
#     443 The connection is instrumented such that when its
#    (...)    446
#     447 """
# --> 448 return _ConnectionFairy._checkout(self)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1271 if not fairy:
# -> 1272     fairy = _ConnectionRecord.checkout(pool)
#    1274     if threadconns is not None:
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     174 try:
# --> 175     return self._create_connection()
#     176 except:
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     387 """Called by subclasses to create a new ConnectionRecord."""
# --> 389 return _ConnectionRecord(self)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#
# OperationalError: connection to server at "172.16.100.21", port 5432 failed: Connection timed out (0x0000274C/10060)
# 	Is the server running on that host and accepting TCP/IP connections?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[46], line 2
#       1 print("Part 1 최적화 시작...")
# ----> 2 place_study = optuna.create_study(
#       3     study_name="place_study_efficientnet",
#       4     storage="postgresql+psycopg2://duruser:durpass@172.16.100.21:5432/place",
#       5     load_if_exists=True,
#       6     direction="minimize",
#       7 )
#       8 place_study.optimize(lambda t: objective(t, target_part=1), n_trials=n_trials)
#      11 print("\nPart 2 최적화 시작...")
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\optuna\_convert_positional_args.py:134, in convert_positional_args.<locals>.converter_decorator.<locals>.converter_wrapper(*args, **kwargs)
#     128     raise TypeError(
#     129         f"{func.__name__}() got multiple values for arguments {duplicated_kwds}."
#     130     )
#     132 kwargs.update(inferred_kwargs)
# --> 134 return func(**kwargs)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\optuna\study\study.py:1295, in create_study(storage, sampler, pruner, study_name, direction, load_if_exists, directions)
#    1286     raise ValueError(
#    1287         f"`directions` must be a list of `minimize` or `maximize`, but got {directions}. "
#    1288         "For single-objective optimization, please use `direction` instead of `directions`."
#    1289     )
#    1291 direction_objects = [
#    1292     d if isinstance(d, StudyDirection) else StudyDirection[d.upper()] for d in directions
#    1293 ]
# -> 1295 storage = storages.get_storage(storage)
#    1296 try:
#    1297     study_id = storage.create_new_study(direction_objects, study_name)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\optuna\storages\__init__.py:49, in get_storage(storage)
#      45     if storage.startswith("redis"):
#      46         raise ValueError(
#      47             "RedisStorage is removed at Optuna v3.1.0. Please use JournalRedisBackend instead."
#      48         )
# ---> 49     return _CachedStorage(RDBStorage(storage))
#      50 elif isinstance(storage, RDBStorage):
#      51     return _CachedStorage(storage)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\optuna\storages\_rdb\storage.py:241, in RDBStorage.__init__(self, url, engine_kwargs, skip_compatibility_check, heartbeat_interval, grace_period, failed_trial_callback, skip_table_creation)
#     237 self.scoped_session = sqlalchemy_orm.scoped_session(
#     238     sqlalchemy_orm.sessionmaker(bind=self.engine)
#     239 )
#     240 if not skip_table_creation:
# --> 241     models.BaseModel.metadata.create_all(self.engine)
#     243 self._version_manager = _VersionManager(self.url, self.engine, self.scoped_session)
#     244 if not skip_compatibility_check:
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\sql\schema.py:5928, in MetaData.create_all(self, bind, tables, checkfirst)
#    5904 def create_all(
#    5905     self,
#    5906     bind: _CreateDropBind,
#    5907     tables: Optional[_typing_Sequence[Table]] = None,
#    5908     checkfirst: bool = True,
#    5909 ) -> None:
#    5910     """Create all tables stored in this metadata.
#    5911
#    5912     Conditional by default, will not attempt to recreate tables already
#    (...)   5926
#    5927     """
# -> 5928     bind._run_ddl_visitor(
#    5929         ddl.SchemaGenerator, self, checkfirst=checkfirst, tables=tables
#    5930     )
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3267, in Engine._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    3261 def _run_ddl_visitor(
#    3262     self,
#    3263     visitorcallable: Type[InvokeDDLBase],
#    3264     element: SchemaVisitable,
#    3265     **kwargs: Any,
#    3266 ) -> None:
# -> 3267     with self.begin() as conn:
#    3268         conn._run_ddl_visitor(visitorcallable, element, **kwargs)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3257, in Engine.begin(self)
#    3232 @contextlib.contextmanager
#    3233 def begin(self) -> Iterator[Connection]:
#    3234     """Return a context manager delivering a :class:`_engine.Connection`
#    3235     with a :class:`.Transaction` established.
#    3236
#    (...)   3255
#    3256     """  # noqa: E501
# -> 3257     with self.connect() as conn:
#    3258         with conn.begin():
#    3259             yield conn
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3293, in Engine.connect(self)
#    3270 def connect(self) -> Connection:
#    3271     """Return a new :class:`_engine.Connection` object.
#    3272
#    3273     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3290
#    3291     """
# -> 3293     return self._connection_cls(self)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
# --> 145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#     148         raise
#     149 else:
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2448, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2446 elif should_wrap:
#    2447     assert sqlalchemy_exception is not None
# -> 2448     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2449 else:
#    2450     assert exc_info[1] is not None
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3317, in Engine.raw_connection(self)
#    3295 def raw_connection(self) -> PoolProxiedConnection:
#    3296     """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298     The returned object is a proxied version of the DBAPI
#    (...)   3315
#    3316     """
# -> 3317     return self.pool.connect()
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     440 def connect(self) -> PoolProxiedConnection:
#     441     """Return a DBAPI connection from the pool.
#     442
#     443     The connection is instrumented such that when its
#    (...)    446
#     447     """
# --> 448     return _ConnectionFairy._checkout(self)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1264 @classmethod
#    1265 def _checkout(
#    1266     cls,
#    (...)   1269     fairy: Optional[_ConnectionFairy] = None,
#    1270 ) -> _ConnectionFairy:
#    1271     if not fairy:
# -> 1272         fairy = _ConnectionRecord.checkout(pool)
#    1274         if threadconns is not None:
#    1275             threadconns.current = weakref.ref(fairy)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175     return self._create_connection()
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#     179     raise
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     386 def _create_connection(self) -> ConnectionPoolEntry:
#     387     """Called by subclasses to create a new ConnectionRecord."""
# --> 389     return _ConnectionRecord(self)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     665     return dialect.connect(*mutable_cargs, **mutable_cparams)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "172.16.100.21", port 5432 failed: Connection timed out (0x0000274C/10060)
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ## 학습시작

# %%
# --- Part 1 최적화 (레이블 1~6) ---
print("Part 1 최적화 시작...")
study1 = optuna.create_study(direction="minimize")
study1.optimize(lambda t: objective(t, target_part=1), n_trials=n_trials)
print(f"Part 1 최적 파라미터: {study1.best_params}")

# # --- Part 2 최적화 (레이블 7~12) ---
# print("\nPart 2 최적화 시작...")
# study2 = optuna.create_study(direction="minimize")
# study2.optimize(lambda t: objective(t, target_part=2), n_trials=n_trials)
# print(f"Part 2 최적 파라미터: {study2.best_params}")
# Out:
# [I 2026-03-10 14:18:07,929] A new study created in memory with name: no-name-cba1ee52-fe25-4ebe-bb40-d6087482ee9c
# Part 1 최적화 시작...
# Epoch 1/1:   0%|          | 0/100 [00:00<?, ?it/s]
# [W 2026-03-10 14:24:14,395] Trial 0 failed with parameters: {'lr': 0.0001671073929330507, 'batch_size': 128} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\potenup3\prj_deep\.venv\Lib\site-packages\optuna\study\_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_12588\1040884344.py", line 4, in <lambda>
#     study1.optimize(lambda t: objective(t, target_part=1), n_trials=n_trials)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_12588\2481599482.py", line 41, in objective
#     for imgs, labels1, labels2 in tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS}"):
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\potenup3\prj_deep\.venv\Lib\site-packages\tqdm\notebook.py", line 250, in __iter__
#     yield from it
#   File "c:\potenup3\prj_deep\.venv\Lib\site-packages\tqdm\std.py", line 1181, in __iter__
#     for obj in iterable:
#                ^^^^^^^^
#   File "c:\potenup3\prj_deep\.venv\Lib\site-packages\torch\utils\data\dataloader.py", line 741, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "c:\potenup3\prj_deep\.venv\Lib\site-packages\torch\utils\data\dataloader.py", line 801, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\potenup3\prj_deep\.venv\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 52, in fetch
#     data = self.dataset.__getitems__(possibly_batched_index)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\potenup3\prj_deep\.venv\Lib\site-packages\torch\utils\data\dataset.py", line 413, in __getitems__
#     return [self.dataset[self.indices[idx]] for idx in indices]
#             ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_12588\2502298794.py", line 20, in __getitem__
#     image = Image.open(img_path).convert('RGB')
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\potenup3\prj_deep\.venv\Lib\site-packages\PIL\Image.py", line 967, in convert
#     self.load()
#   File "c:\potenup3\prj_deep\.venv\Lib\site-packages\PIL\ImageFile.py", line 406, in load
#     n, err_code = decoder.decode(b)
#                   ^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# [W 2026-03-10 14:24:14,715] Trial 0 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 4
#       2 print("Part 1 최적화 시작...")
#       3 study1 = optuna.create_study(direction="minimize")
# ----> 4 study1.optimize(lambda t: objective(t, target_part=1), n_trials=n_trials)
#       5 print(f"Part 1 최적 파라미터: {study1.best_params}")
#       7 # # --- Part 2 최적화 (레이블 7~12) ---
#       8 # print("\nPart 2 최적화 시작...")
#       9 # study2 = optuna.create_study(direction="minimize")
#      10 # study2.optimize(lambda t: objective(t, target_part=2), n_trials=n_trials)
#      11 # print(f"Part 2 최적 파라미터: {study2.best_params}")
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\optuna\study\study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\optuna\study\_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\optuna\study\_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\optuna\study\_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\optuna\study\_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# Cell In[11], line 4, in <lambda>(t)
#       2 print("Part 1 최적화 시작...")
#       3 study1 = optuna.create_study(direction="minimize")
# ----> 4 study1.optimize(lambda t: objective(t, target_part=1), n_trials=n_trials)
#       5 print(f"Part 1 최적 파라미터: {study1.best_params}")
#       7 # # --- Part 2 최적화 (레이블 7~12) ---
#       8 # print("\nPart 2 최적화 시작...")
#       9 # study2 = optuna.create_study(direction="minimize")
#      10 # study2.optimize(lambda t: objective(t, target_part=2), n_trials=n_trials)
#      11 # print(f"Part 2 최적 파라미터: {study2.best_params}")
#
# Cell In[10], line 41, in objective(trial, target_part)
#      38 train_correct = 0
#      39 train_total = 0
# ---> 41 for imgs, labels1, labels2 in tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS}"):
#      42     imgs = imgs.to(DEVICE)
#      43     # target_part 값에 따라 레이블 선택
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\tqdm\notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     yield from it
#     251 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#     252 except:  # NOQA
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\torch\utils\data\dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\torch\utils\data\dataloader.py:801, in _SingleProcessDataLoaderIter._next_data(self)
#     799 def _next_data(self):
#     800     index = self._next_index()  # may raise StopIteration
# --> 801     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802     if self._pin_memory:
#     803         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50 if self.auto_collation:
#      51     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 52         data = self.dataset.__getitems__(possibly_batched_index)
#      53     else:
#      54         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\torch\utils\data\dataset.py:413, in Subset.__getitems__(self, indices)
#     411     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     412 else:
# --> 413     return [self.dataset[self.indices[idx]] for idx in indices]
#
# Cell In[8], line 20, in MultiLabelDataset.__getitem__(self, idx)
#      18 img_name = self.df.iloc[idx]['file_name']
#      19 img_path = f"{self.img_dir}/{img_name}"
# ---> 20 image = Image.open(img_path).convert('RGB')
#      22 labels1 = torch.tensor(self.df.iloc[idx][self.labels_p1].values.astype(float), dtype=torch.float32)
#      23 labels2 = torch.tensor(self.df.iloc[idx][self.labels_p2].values.astype(float), dtype=torch.float32)
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\PIL\Image.py:967, in Image.convert(self, mode, matrix, dither, palette, colors)
#     915 def convert(
#     916     self,
#     917     mode: str | None = None,
#    (...)    921     colors: int = 256,
#     922 ) -> Image:
#     923     """
#     924     Returns a converted copy of this image. For the "P" mode, this
#     925     method translates pixels through the palette.  If mode is
#    (...)    964     :returns: An :py:class:`~PIL.Image.Image` object.
#     965     """
# --> 967     self.load()
#     969     has_transparency = "transparency" in self.info
#     970     if not mode and self.mode == "P":
#     971         # determine default mode
#
# File c:\potenup3\prj_deep\.venv\Lib\site-packages\PIL\ImageFile.py:406, in ImageFile.load(self)
#     403         raise OSError(msg)
#     405 b = b + s
# --> 406 n, err_code = decoder.decode(b)
#     407 if n < 0:
#     408     break
#
# KeyboardInterrupt:
# notebook controller is DISPOSED.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
# notebook controller is DISPOSED.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
# notebook controller is DISPOSED.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
